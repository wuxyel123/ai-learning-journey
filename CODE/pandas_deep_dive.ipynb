# %% [markdown]
# # Pandas Deep Dive

# %%
import pandas as pd
import numpy as np

# %%
# Create a sample DataFrame

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 40, 29],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR'],
    'Salary': [50000, 60000, 75000, 80000, 52000]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age Department  Salary
# 0    Alice   25         HR   50000
# 1      Bob   30         IT   60000
# 2  Charlie   35         IT   75000
# 3    David   40    Finance   80000
# 4      Eva   29         HR   52000

# %%
# Indexing and Selection
print(df[['Name', 'Salary']])
print(df[df['Age'] > 30])
# Out:
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   75000
# 3    David   80000
# 4      Eva   52000
#       Name  Age Department  Salary
# 2  Charlie   35         IT   75000
# 3    David   40    Finance   80000

# %%
# Grouping and Aggregation
print(df.groupby('Department')['Salary'].mean())
# Out:
# Department
# Finance    80000.0
# HR         51000.0
# IT         67500.0
# Name: Salary, dtype: float64

# %%
# Merging DataFrames
extra = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Eva'],
    'Bonus': [2000, 3000, 2500, 1800]
})

merged = pd.merge(df, extra, on='Name', how='left')
merged
# Out:
#       Name  Age Department  Salary   Bonus
# 0    Alice   25         HR   50000  2000.0
# 1      Bob   30         IT   60000  3000.0
# 2  Charlie   35         IT   75000  2500.0
# 3    David   40    Finance   80000     NaN
# 4      Eva   29         HR   52000  1800.0

# %%
# Simple Visualization
import matplotlib.pyplot as plt

merged.plot(x='Name', y='Salary', kind='bar', title='Salaries')
plt.tight_layout()
plt.show()
